# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarissa2467/sistem-panen/blob/fitur-diskon/fitur_diskon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hitung_total(panen):
    return sum(panen)


def hitung_diskon(total, persentase_diskon):
    return total * (1 - persentase_diskon / 100)


hasil_panen = [120, 150, 100, 130]
total = hitung_total(hasil_panen)
total_setelah_diskon = hitung_diskon(total, 10)

print("Total hasil panen:", total, "kg")
print("Total setelah diskon 10%:", total_setelah_diskon, "kg")
# Out:
# Total hasil panen: 500 kg
# Total setelah diskon 10%: 450.0 kg
