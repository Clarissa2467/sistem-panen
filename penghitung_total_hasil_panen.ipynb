# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarissa2467/sistem-panen/blob/main/penghitung_total_hasil_panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hitung_total(panen):
    return sum(panen)


hasil_panen = [120, 150, 100, 130]
total = hitung_total(hasil_panen)

print("Total hasil panen:", total, "kg")
# Out:
# Total hasil panen: 500 kg
